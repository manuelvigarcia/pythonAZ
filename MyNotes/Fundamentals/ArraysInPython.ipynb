# %% [markdown]
# # Arrays in Python
#
# Besides lists, python also has arrays, which are list of elements of the same type

# %%
l=[2345, 27, 546, 215, -1234]

# %%
import numpy as np

# %%
a=np.array(l)
a
# Out:
# array([ 2345,    27,   546,   215, -1234])

# %%
b= np.array([12,455,63.3,True,'abc'])

# %%
b
# Out:
# array(['12', '455', '63.3', 'True', 'abc'], dtype='<U32')

# %% [markdown]
# All have been converted to strings, which is a type that can accomodate all of them, in order to have the same type for all elements

# %%
type(b)
# Out:
# numpy.ndarray

# %% [markdown]
# ---

# %% [markdown]
# ## Array slicing
# This creates a reference to the original array, so modifying the original, modifies the slice.

# %%
a
# Out:
# array([ 2345,    27,   546,   215, -1234])

# %%
b
# Out:
# array(['12', '455', '63.3', 'True', 'abc'], dtype='<U32')

# %%
c = a[2:4]
c
# Out:
# array([546, 215])

# %%
c[0]
# Out:
# np.int64(546)

# %%
c[:]
# Out:
# array([546, 215])

# %%
c[:] = 111
c
# Out:
# array([111, 111])

# %%
a
# Out:
# array([ 2345,    27,   111,   111, -1234])

# %% [markdown]
# Array a has been modified through the slice c

# %%
d = a.copy()
d
# Out:
# array([ 2345,    27,   111,   111, -1234])

# %%
# modify d
d[0]= 0
d
# Out:
# array([    0,    27,   111,   111, -1234])

# %%
# a stays the same
a
# Out:
# array([ 2345,    27,   111,   111, -1234])
