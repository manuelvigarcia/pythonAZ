# %% [markdown]
# # Tuples

# %%
letters = ['A','B','C','D','E','F','G','H','I','J']

# %%
letters[::3]
# Out:
# ['A', 'D', 'G', 'J']

# %%
letters[::-1]
# Out:
# ['J', 'I', 'H', 'G', 'F', 'E', 'D', 'C', 'B', 'A']

# %%
letters[2:7:1]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
letters[2:7:-1]
# Out:
# []

# %%
letters[7:2:-1]
# Out:
# ['H', 'G', 'F', 'E', 'D']

# %%
#to get the same as before, reversed
letters[6:1:-1]
# Out:
# ['G', 'F', 'E', 'D', 'C']

# %% [markdown]
# ---

# %%
#tuple= immutable list
t1=(345,674,934)
t1
# Out:
# (345, 674, 934)

# %%
t1[0]
# Out:
# 345

# %%
t1[1]
# Out:
# 674

# %%
t1[1]=45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t1[1]=45
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# TypeError: 'tuple' object does not support item assignment
