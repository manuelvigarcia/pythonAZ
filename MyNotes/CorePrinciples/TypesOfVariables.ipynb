# %% [markdown]
# # Types of Variables

# %%
#integer
x = 2

# %%
x
# Out:
# 2

# %%
type(x)
# Out:
# int

# %% [markdown]
# ---

# %%
#float / double 
y = 2.5

# %%
y
# Out:
# 2.5

# %%
type(y)
# Out:
# float

# %% [markdown]
# ---

# %%
# string
a = "hello"
b = 'hello'

# %%
a
# Out:
# 'hello'

# %%
b
# Out:
# 'hello'

# %%
a == b
# Out:
# True

# %%
c='2'

# %%
c
# Out:
# '2'

# %%
type(c)
# Out:
# str

# %% [markdown]
# ---

# %%
# logical /  boolean
ql = True

# %%
ql
# Out:
# True

# %%
type(ql)
# Out:
# bool
