# %% [markdown]
# # Boolean variables and Operators

# %%
# Boolean / Logical:
# True
# False

# %%
4 < 4
# Out:
# False

# %%
100 > 1000
# Out:
# False

# %%
4 == 5
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
4 <= 5
# Out:
# True

# %% [markdown]
# ---

# %%
result = 4 < 5

# %%
result
# Out:
# True

# %%
type (result)
# Out:
# bool

# %% [markdown]
# ---

# %%
result2 = not(5 > 1)

# %%
result2
# Out:
# False

# %% [markdown]
# ---

# %%
result or result2
# Out:
# True

# %%
result and result2
# Out:
# False
