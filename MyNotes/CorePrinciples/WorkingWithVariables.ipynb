# %% [markdown]
# # Working with Variables

# %%
A = 10
B = 5

# %%
# Arithmetics
C = A + B

# %%
D = B / A  # division is not integer division since Python 3.0

# %% [markdown]
# ---

# %%
#Printing

# %%
C
# Out:
# 15

# %%
print(C)
# Out:
# 15

# %%
print(D)
# Out:
# 0.5

# %% [markdown]
# ---

# %%
import math

# %%
math.sqrt(A)
# Out:
# 3.1622776601683795

# %%
math.sqrt(144)
# Out:
# 12.0

# %%
round(math.sqrt(A))
# Out:
# 3

# %%
greeting = "Hello"

# %%
name = "Bob"

# %%
message = greeting + ' ' + name
message
# Out:
# 'Hello Bob'
